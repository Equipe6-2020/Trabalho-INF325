# %%
# %env MONGODB_VERSION      4.0.11
# %env MONGODB_PATH mongodb-4.0.11
# Out:
# env: MONGODB_VERSION=4.0.11
# env: MONGODB_PATH=mongodb-4.0.11

# %%
# !${MONGODB_PATH}/bin/mongo --help
# Out:
# MongoDB shell version v4.0.11
# usage: mongodb-4.0.11/bin/mongo [options] [db address] [file names (ending in .js)]
# db address can be:
#   foo                   foo database on local machine
#   192.168.0.5/foo       foo database on 192.168.0.5 machine
#   192.168.0.5:9999/foo  foo database on 192.168.0.5 machine on port 9999
# Options:
#   --shell                             run the shell after executing files
#   --nodb                              don't connect to mongod on startup - no
#                                       'db address' arg expected
#   --norc                              will not run the ".mongorc.js" file on
#                                       start up
#   --quiet                             be less chatty
#   --port arg                          port to connect to
#   --host arg                          server to connect to
#   --eval arg                          evaluate javascript
#   -h [ --help ]                       show this usage information
# ...

# %%
# !${MONGODB_PATH}/bin/mongo --eval "printjson(db.serverStatus())"
# Out:
# MongoDB shell version v4.0.11
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("a5fa5751-e906-4326-b79a-6819ee48a0e1") }
# MongoDB server version: 4.0.11
# {
# 	"host" : "jep",
# 	"version" : "4.0.11",
# 	"process" : "mongod",
# 	"pid" : NumberLong(9049),
# 	"uptime" : 204,
# 	"uptimeMillis" : NumberLong(203618),
# 	"uptimeEstimate" : NumberLong(203),
# 	"localTime" : ISODate("2020-09-09T01:05:23.309Z"),
# 	"asserts" : {
# 		"regular" : 0,
# 		"warning" : 0,
# 		"msg" : 0,
# 		"user" : 1,
# 		"rollovers" : 0
# 	},
# 	"connections" : {
# 		"current" : 1,
# 		"available" : 3275,
# 		"totalCreated" : 1,
# 		"active" : 1
# 	},
# 	"extra_info" : {
# 		"note" : "fields vary by platform",
# 		"page_faults" : 4
# 	},
# 	"freeMonitoring" : {
# 		"state" : "undecided"
# 	},
# 	"globalLock" : {
# 		"totalTime" : NumberLong(203616000),
# 		"currentQueue" : {
# 			"total" : 0,
# 			"readers" : 0,
# 			"writers" : 0
# 		},
# ...

# %%
# !mongoimport --db test --collection products --drop --file ./csvjson.json
# Out:
# 2020-09-08T22:08:08.268-0300	connected to: mongodb://localhost/
# 2020-09-08T22:08:08.269-0300	dropping: test.products
# 2020-09-08T22:08:08.362-0300	Failed: cannot decode array into a D
# 2020-09-08T22:08:08.362-0300	0 document(s) imported successfully. 0 document(s) failed to import.

# %%
# !mongoimport --db test --collection products --drop --jsonArray --file csvjson.json
# Out:
# 2020-09-08T22:22:27.132-0300	connected to: mongodb://localhost/
# 2020-09-08T22:22:27.133-0300	dropping: test.products
# 2020-09-08T22:22:28.309-0300	32951 document(s) imported successfully. 0 document(s) failed to import.
